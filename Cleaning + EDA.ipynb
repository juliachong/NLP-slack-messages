# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import train_test_split
from matplotlib import cm
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
import pandas as pd
wfh = pd.read_csv('wfh.csv')
wfh.columns = ['msg', 'date', 'time']

# %% [markdown]
# # Lowercase all messages

# %%
lower_bank = []
for i in range(len(wfh)):
    lower_msg = wfh['msg'][i].lower()
    lower_bank.append(lower_msg)
wfh['msg'] = lower_bank

# %% [markdown]
# # Separate words in each message

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'[a-zA-Z0-9]+')

tokenized_msg = []
for i in wfh['msg']:
    token_msg = tokenizer.tokenize(i)
    tokenized_msg.append(token_msg)
tokenized_messages = tokenized_msg

# %% [markdown]
# # Create WordBank of all separated words from all messages

# %%
all_words = []
for i in tokenized_messages:
    for j in i:
        all_words.append(j)

# %%
nltk.download('stopwords')
stop_words=set(stopwords.words("english"))
stop_words=(stopwords.words("english"))
wfh_stopwords = ['hey', 'all', 'today', 'day', 'convene', 'morning', 'afternoon', 'tomorrow']
for i in range(len(wfh_stopwords)):
    stop_words.append(wfh_stopwords[i])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/juliachong/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stpwrd = []
for w in tokenized_messages:
    for j in w:
        if j not in stop_words:
            stpwrd.append(w)

# %%
import itertools
merged = list(itertools.chain(*stpwrd))

# %%
word_freqdist = FreqDist(stpwrd)
word_freqdist
# Out:
# FreqDist({'wfh': 43, 'going': 31, 'take': 16, 'feeling': 16, 'home': 14, 'need': 13, 'dana': 10, 'later': 9, 'lilly': 9, 'get': 9, ...})

# %%
word = word_freqdist.keys()
count = word_freqdist.values()

word = df['word']
count = df['count']

# %%
# TF IDF VISUALIZATION
import seaborn as sns
from matplotlib import pyplot as plt

new_figure = plt.figure(figsize=(16,4))

ax = new_figure.add_subplot(121)
ax.title.set_text('Most Common Words')
color = cm.viridis_r(np.linspace(.4,.8, 30))
ax.bar(word[0:20], count[0:20], color=color)
# ax.plot(colormap='PRGn')

# Draw a scatter plot on 2nd axes
for ax in new_figure.axes:
    plt.sca(ax)
    plt.xticks(rotation=60)

# %%
df = pd.DataFrame(list(zip(word, count)), 
               columns =['word', 'count'])

# %%
df = df.sort_values(by=['count'], ascending=False)

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(colormap='Spectral').generate_from_frequencies(word_freqdist)

# Display the generated image w/ matplotlib:

plt.figure(figsize=(10,10), facecolor='k')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)

# %%
heads_msg = []
for i in tokenized_msg:
    for j in i:
        if j in heads_down_time:
            heads_msg.append(i)

# %%
stpwrd = []
for w in tokenized_messages:
    for j in w:
        if j not in stop_words:
            stpwrd.append(w)

# %%
hospital = ['hospital', 'ER', 'doctor']
feeling = ['feeling', 'good', 'weather', 'well', 'great']
family = ['dana', 'lilly', 'school']
wfh = ['wfh', 'home']
standup = ['standup']
running_late = ['running', 'late']
transportation = ['flight', 'train']

# %%
len(hospital_msg)
# Out:
# 7

# %%
len(feeling_msg)
# Out:
# 30

# %%
wfh['msg']
# Out:
# 0      Hey all, I took a pretty nasty spill coming in...
# 1      Hey all, my stomach is in knots this morning. ...
# 2      Hey all, still not feeling super great. I’m go...
# 3      Hey all, Dana stayed in the hospital over nigh...
# 4      Hey all, Dana and I have to go to Isaacs schoo...
#                              ...
# 97     Hey all, I’m running late, and will miss stand...
# 98     Train delays got me this morning. I’ll try to ...
# 99                           Convene later this morning.
# 100    Feel better Milan. I’ll be working from 524 to...
# 101    Hey all, running a few minutes late to standup...
# Name: msg, Length: 102, dtype: object

# %%
for message in family_msg:
    for sentence in message:
            print(sentence + '\n')
# Out:
# hey
#
# all
#
# dana
#
# stayed
#
# in
#
# the
#
# hospital
#
# over
#
# night
#
# so
#
# i
#
# will
#
# be
#
# working
#
# from
#
# there
#
# today
#
# i
#
# ll
#
# let
#
# you
#
# know
#
# if
#
# i
#
# can
#
# t
#
# attend
#
# a
#
# meeting
#
# hey
#
# all
#
# dana
#
# and
#
# i
#
# have
#
# to
#
# go
#
# to
#
# isaacs
#
# school
#
# tomorrow
#
# morning
#
# to
#
# deal
#
# with
#
# a
#
# bullying
#
# issue
#
# i
#
# should
#
# be
#
# in
#
# the
#
# office
#
# late
#
# morning
#
# hey
#
# all
#
# dana
#
# and
#
# i
#
# have
#
# to
#
# go
#
# to
#
# isaacs
#
# school
#
# tomorrow
#
# morning
#
# to
#
# deal
#
# with
#
# a
#
# bullying
#
# issue
#
# i
#
# should
#
# be
#
# in
#
# the
#
# office
#
# late
#
# morning
#
# hi
#
# all
#
# i
#
# got
#
# my
#
# weeks
#
# mixed
#
# up
#
# dana
#
# is
#
# having
#
# hernia
#
# surgery
#
# tomorrow
#
# at
#
# 9am
#
# i
#
# will
#
# be
#
# at
#
# the
#
# hospital
#
# with
#
# her
#
# i
#
# will
#
# be
#
# working
#
# when
#
# i
#
# can
#
# but
#
# i
#
# will
#
# have
#
# to
#
# play
#
# which
#
# meetings
#
# i
#
# can
#
# attend
#
# by
#
# ear
#
# hey
#
# all
#
# i
#
# just
#
# got
#
# back
#
# from
#
# the
#
# hospital
#
# with
#
# lilly
#
# she
#
# has
#
# major
#
# back
#
# pain
#
# again
#
# tonight
#
# and
#
# needed
#
# to
#
# be
#
# seen
#
# i
#
# am
#
# going
#
# to
#
# take
#
# tomorrow
#
# off
#
# so
#
# i
#
# can
#
# help
#
# get
#
# her
#
# to
#
# her
#
# orthopedist
#
# show
#
# more
#
# hey
#
# all
#
# with
#
# the
#
# games
#
# isaac
#
# is
#
# playing
#
# be
#
# happy
#
# to
#
# tell
#
# you
#
# this
#
# story
#
# sometime
#
# and
#
# dana
#
# being
#
# sick
#
# i
#
# m
#
# going
#
# to
#
# wfh
#
# so
#
# i
#
# can
#
# be
#
# close
#
# to
#
# isaacs
#
# school
#
# if
#
# i
#
# need
#
# to
#
# take
#
# care
#
# of
#
# things
#
# hey
#
# all
#
# with
#
# the
#
# games
#
# isaac
#
# is
#
# playing
#
# be
#
# happy
#
# to
#
# tell
#
# you
#
# this
#
# story
#
# sometime
#
# and
#
# dana
#
# being
#
# sick
#
# i
#
# m
#
# going
#
# to
#
# wfh
#
# so
#
# i
#
# can
#
# be
#
# close
#
# to
#
# isaacs
#
# school
#
# if
#
# i
#
# need
#
# to
#
# take
#
# care
#
# of
#
# things
#
# hey
#
# all
#
# change
#
# of
#
# plans
#
# today
#
# my
#
# wife
#
# woke
#
# up
#
# not
#
# feeling
#
# well
#
# i
#
# will
#
# need
#
# to
#
# stay
#
# home
#
# and
#
# help
#
# with
#
# lilly
#
# since
#
# she
#
# is
#
# having
#
# trouble
#
# doing
#
# everything
#
# herself
#
# right
#
# now
#
# because
#
# of
#
# her
#
# back
#
# hey
#
# all
#
# i
#
# m
#
# on
#
# my
#
# way
#
# to
#
# convene
#
# today
#
# was
#
# dana
#
# s
#
# first
#
# day
#
# without
#
# any
#
# help
#
# and
#
# the
#
# kids
#
# are
#
# off
#
# school
#
# so
#
# i
#
# wanted
#
# to
#
# make
#
# sure
#
# it
#
# was
#
# going
#
# to
#
# go
#
# ok
#
# thanks
#
# for
#
# your
#
# patience
#
# grinning
#
# hey
#
# all
#
# i
#
# m
#
# on
#
# my
#
# way
#
# to
#
# convene
#
# today
#
# was
#
# dana
#
# s
#
# first
#
# day
#
# without
#
# any
#
# help
#
# and
#
# the
#
# kids
#
# are
#
# off
#
# school
#
# so
#
# i
#
# wanted
#
# to
#
# make
#
# sure
#
# it
#
# was
#
# going
#
# to
#
# go
#
# ok
#
# thanks
#
# for
#
# your
#
# patience
#
# grinning
#
# hey
#
# all
#
# dana
#
# is
#
# home
#
# now
#
# it
#
# was
#
# a
#
# long
#
# night
#
# though
#
# so
#
# i
#
# m
#
# going
#
# to
#
# take
#
# the
#
# morning
#
# off
#
# i
#
# m
#
# planning
#
# on
#
# being
#
# into
#
# convene
#
# early
#
# afternoon
#
# hey
#
# all
#
# we
#
# had
#
# to
#
# take
#
# lilly
#
# into
#
# the
#
# hospital
#
# late
#
# last
#
# night
#
# for
#
# severe
#
# back
#
# pain
#
# so
#
# i
#
# m
#
# going
#
# to
#
# wfh
#
# again
#
# today
#
# wfh
#
# today
#
# lilly
#
# was
#
# not
#
# feeling
#
# great
#
# when
#
# she
#
# went
#
# to
#
# school
#
# so
#
# i
#
# need
#
# to
#
# stay
#
# nearby
#
# incase
#
# she
#
# has
#
# to
#
# be
#
# picked
#
# up
#
# wfh
#
# today
#
# lilly
#
# was
#
# not
#
# feeling
#
# great
#
# when
#
# she
#
# went
#
# to
#
# school
#
# so
#
# i
#
# need
#
# to
#
# stay
#
# nearby
#
# incase
#
# she
#
# has
#
# to
#
# be
#
# picked
#
# up
#
# hey
#
# all
#
# i
#
# ll
#
# be
#
# at
#
# convene
#
# around
#
# 10
#
# today
#
# sorry
#
# i
#
# ve
#
# been
#
# getting
#
# in
#
# a
#
# little
#
# later
#
# the
#
# past
#
# few
#
# days
#
# lilly
#
# had
#
# to
#
# start
#
# a
#
# home
#
# private
#
# school
#
# so
#
# i
#
# ve
#
# been
#
# helping
#
# with
#
# technology
#
# issues
#
# hey
#
# all
#
# i
#
# ll
#
# be
#
# at
#
# convene
#
# around
#
# 10
#
# today
#
# sorry
#
# i
#
# ve
#
# been
#
# getting
#
# in
#
# a
#
# little
#
# later
#
# the
#
# past
#
# few
#
# days
#
# lilly
#
# had
#
# to
#
# start
#
# a
#
# home
#
# private
#
# school
#
# so
#
# i
#
# ve
#
# been
#
# helping
#
# with
#
# technology
#
# issues
#
# i
#
# m
#
# wfh
#
# again
#
# today
#
# yesterday
#
# lilly
#
# was
#
# holding
#
# beefcake
#
# and
#
# fell
#
# all
#
# the
#
# way
#
# down
#
# our
#
# stairs
#
# and
#
# we
#
# had
#
# to
#
# take
#
# her
#
# to
#
# the
#
# er
#
# so
#
# is
#
# ok
#
# except
#
# for
#
# a
#
# sprained
#
# ankle
#
# dana
#
# had
#
# a
#
# doctor
#
# s
#
# show
#
# more
#
# i
#
# m
#
# wfh
#
# again
#
# today
#
# yesterday
#
# lilly
#
# was
#
# holding
#
# beefcake
#
# and
#
# fell
#
# all
#
# the
#
# way
#
# down
#
# our
#
# stairs
#
# and
#
# we
#
# had
#
# to
#
# take
#
# her
#
# to
#
# the
#
# er
#
# so
#
# is
#
# ok
#
# except
#
# for
#
# a
#
# sprained
#
# ankle
#
# dana
#
# had
#
# a
#
# doctor
#
# s
#
# show
#
# more
#
# hey
#
# all
#
# dana
#
# is
#
# having
#
# some
#
# tests
#
# run
#
# in
#
# the
#
# morning
#
# and
#
# i
#
# am
#
# going
#
# with
#
# her
#
# i
#
# will
#
# try
#
# to
#
# be
#
# available
#
# but
#
# it
#
# kinda
#
# depends
#
# on
#
# the
#
# wifi
#
# situation
#
# when
#
# we
#
# get
#
# there
#
# hey
#
# all
#
# i
#
# am
#
# going
#
# to
#
# be
#
# offline
#
# for
#
# about
#
# an
#
# hour
#
# dana
#
# and
#
# i
#
# have
#
# to
#
# go
#
# down
#
# to
#
# the
#
# welcome
#
# center
#
# because
#
# they
#
# are
#
# not
#
# returning
#
# our
#
# phone
#
# calls
#
# for
#
# lilly
#
# s
#
# transfer
#
# hey
#
# all
#
# i
#
# am
#
# going
#
# to
#
# be
#
# offline
#
# for
#
# about
#
# an
#
# hour
#
# dana
#
# and
#
# i
#
# have
#
# to
#
# go
#
# down
#
# to
#
# the
#
# welcome
#
# center
#
# because
#
# they
#
# are
#
# not
#
# returning
#
# our
#
# phone
#
# calls
#
# for
#
# lilly
#
# s
#
# transfer
#
# i
#
# m
#
# going
#
# to
#
# wfh
#
# this
#
# morning
#
# and
#
# then
#
# maybe
#
# come
#
# in
#
# in
#
# the
#
# afternoon
#
# i
#
# want
#
# to
#
# stay
#
# close
#
# by
#
# home
#
# for
#
# lilly
#
# hey
#
# all
#
# i
#
# need
#
# to
#
# wfh
#
# again
#
# today
#
# we
#
# are
#
# still
#
# trying
#
# to
#
# get
#
# lilly
#
# s
#
# school
#
# resolved
#
# and
#
# i
#
# need
#
# to
#
# stay
#
# close
#
# to
#
# home
#
# to
#
# visit
#
# the
#
# welcome
#
# center
#
# again
#
# face
#
# with
#
# rolling
#
# eyes
#
# hey
#
# all
#
# i
#
# need
#
# to
#
# wfh
#
# again
#
# today
#
# we
#
# are
#
# still
#
# trying
#
# to
#
# get
#
# lilly
#
# s
#
# school
#
# resolved
#
# and
#
# i
#
# need
#
# to
#
# stay
#
# close
#
# to
#
# home
#
# to
#
# visit
#
# the
#
# welcome
#
# center
#
# again
#
# face
#
# with
#
# rolling
#
# eyes
#
# i
#
# m
#
# actually
#
# going
#
# to
#
# be
#
# working
#
# from
#
# home
#
# for
#
# the
#
# full
#
# day
#
# today
#
# we
#
# have
#
# some
#
# appointments
#
# like
#
# getting
#
# the
#
# kids
#
# registered
#
# for
#
# school
#
# through
#
# out
#
# the
#
# day
#
# hey
#
# all
#
# i
#
# m
#
# going
#
# to
#
# actually
#
# wfh
#
# today
#
# dana
#
# is
#
# not
#
# feeling
#
# great
#
# and
#
# the
#
# kids
#
# are
#
# home
#
# from
#
# school
#
# hey
#
# all
#
# i
#
# m
#
# going
#
# to
#
# actually
#
# wfh
#
# today
#
# dana
#
# is
#
# not
#
# feeling
#
# great
#
# and
#
# the
#
# kids
#
# are
#
# home
#
# from
#
# school

# %%
len(wfh_msg)
# Out:
# 57

# %%
len(standup_msg)
# Out:
# 6

# %%
len(running_msg)
# Out:
# 11

# %%
len(trans_msg)
# Out:
# 5

# %%
x = ['hospitalization', 'not feeling well', 'family related', 'no explanation', 'miss standup', 'running late', 'transportation issues']

# %%
y = [7, 30, 27, 57, 6, 11, 5]

# %%
# TF IDF VISUALIZATION
import seaborn as sns
from matplotlib import pyplot as plt

new_figure = plt.figure(figsize=(16,4))

ax = new_figure.add_subplot(121)
ax.title.set_text('Excuses')
color = cm.viridis_r(np.linspace(.4,.8, 30))
ax.bar(x, y, color=color)
# ax.plot(colormap='PRGn')

# Draw a scatter plot on 2nd axes
for ax in new_figure.axes:
    plt.sca(ax)
    plt.xticks(rotation=60)
